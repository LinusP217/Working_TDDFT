# %% [markdown]
# > Density-functional theory uses the electron density to simplify quantum mechanics in a way that computers can handle efficiently and accurately.
# >
# > \- [**John Perdew**](https://www.youtube.com/watch?v=KL67LpuId70), Tulane University

# %%
print("Hello, World!")
# Out:
# Hello, World!
