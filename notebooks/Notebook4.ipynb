# %% [markdown]
# > The goal is approximations that deliver the **right answer** for the **right reason** at the **right price**.
# >
# > \- [**John Perdew**](https://ui.adsabs.harvard.edu/abs/2016nsf....1607868P/abstract#:~:text=But%20more%20accurate%20approximations%20are,pure%20predictions%2C%20and%20not%20fits.), Tulane University

# %%
print("Hello, World!")
# Out:
# Hello, World!
